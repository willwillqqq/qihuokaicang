# %%
# 缺LPG

import requests
import json
import pandas as pd

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=AU2012").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=AU2012").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓沪金")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=CU2011").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=CU2011").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓沪铜")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=ZN2011").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=ZN2011").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓沪锌")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=RU2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=RU2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓橡胶")

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=I2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=I2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓铁矿")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=ZC2011").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=ZC2011").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓郑煤")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=RM2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=RM2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓菜粕")

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=MA2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=MA2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓郑醇")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=TA2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=TA2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓PTA")

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=L2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=L2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓塑料")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=SR2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=SR2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓白糖")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=CF2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=CF2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓郑棉")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=V2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=V2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓PVC")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=PP2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=PP2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓PP")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=C2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=C2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓玉米")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=M2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=M2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓豆粕")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=AL2011").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(50)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=AL2011").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(50)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99 or b>0.99:
    print("准备开仓沪铝")
# Out:
# 准备开仓橡胶
# 准备开仓郑棉
# 准备开仓沪铝

# %%
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=RU2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(25)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=RU2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(25)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if b>0.99:
    print("准备毕仓橡胶")

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=ZC2011").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(25)

data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=ZC2011").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(25)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if b>0.99:
    print("准备毕仓郑煤")
    
data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=TA2101").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data = data.tail(25)
    
data1 = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesMiniKLine5m?symbol=TA2101").content
data1 = json.loads(data1)
data1 = pd.DataFrame(data1)
data1 = data1.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
data1 = data1.head(25)

a=float(data1.loc[data1.index[0], 'close'])/float(max(data.high))
b=float(min(data.low))/float(data1.loc[data1.index[0], 'close'])
if a>0.99:
    print("准备毕仓PTA")

# %%
import requests
import json
import pandas as pd

data = requests.get("http://stock2.finance.sina.com.cn/futures/api/json.php/IndexService.getInnerFuturesDailyKLine?symbol=AU2012").content
data = json.loads(data)
data = pd.DataFrame(data)
data = data.rename(columns = {0: 'time',1:'open',2:'high',3:'low',4:'close',5:'volume'})
print(data)
# Out:
#            time     open     high      low    close  volume
# 0    2020-01-09  362.340  362.340  350.540  351.500     985
# 1    2020-01-10  353.000  355.000  352.400  353.100    2561
# 2    2020-01-13  352.940  355.140  352.500  353.400    1669
# 3    2020-01-14  353.000  353.220  346.800  349.060    1930
# 4    2020-01-15  350.140  352.900  349.660  352.040    1956
# 5    2020-01-16  351.920  353.500  351.320  352.160    2860
# 6    2020-01-17  352.560  352.620  350.620  351.780    4008
# 7    2020-01-20  352.240  352.700  351.260  351.960    1584
# 8    2020-01-21  352.000  356.000  352.000  355.640    1519
# 9    2020-01-22  353.780  354.240  351.200  352.720     848
# 10   2020-01-23  353.440  355.520  353.060  355.040    1178
# 11   2020-02-03  361.100  364.460  361.100  364.100    3518
# 12   2020-02-04  363.100  363.980  360.740  360.820    2454
# 13   2020-02-05  358.340  359.520  356.060  358.620     905
# 14   2020-02-06  356.680  357.160  355.460  356.620    1360
# ...

# %%
data.to_csv('documents/hujin.csv')
